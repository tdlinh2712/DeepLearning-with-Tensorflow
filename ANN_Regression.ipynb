# %% [markdown]
# <a href="https://colab.research.google.com/github/tdlinh2712/DeepLearning-with-Tensorflow/blob/master/ANN_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Make the dataset
N = 1000
X = np.random.random((N, 2)) * 6 - 3 # uniformly distributed between -3 and + 3
Y = np.cos(2*X[:, 0]) + np.cos(3 * X[:,1]) # y = cos(2 * x_1) + cos(3 * x_2)

# %%
# plotting
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], Y)

# %%
from tensorflow.keras import models, layers

# %%
# build the model
model = tf.keras.models.Sequential([
  layers.Dense(128, input_shape=(2,), activation ='relu'),
  layers.Dense(1)
])

# %%
# compile and fit
opt = tf.keras.optimizers.Adam(0.01)

model.compile(optimizer=opt,
             loss='mse')

# %%
#train the model
r = model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 2ms/step - loss: 0.9593
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.8780
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.8643
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.8767
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8190
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7516
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6846
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6490
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5764
# Epoch 10/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5562
# Epoch 11/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5384
# Epoch 12/100
# ...

# %%
plt.plot(r.history['loss'], label='loss')

# %%
# plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:, 0], X[:,1], Y)

# surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
# plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(X[:, 0], X[:,1], Y)

# surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
